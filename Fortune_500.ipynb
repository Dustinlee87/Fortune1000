# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r".\Fortune_1000_DF.csv")

# %%
df.drop(columns=["ceo_founder", "ceo_woman", "Website", "Ticker"], inplace = True)

# %%
df1=df.drop(df.index[501:1000], inplace=True)
print(df)
# Out:
#                      company  rank  rank_change   revenue   profit  \
# 0                    Walmart     1            0  572754.0  13673.0
# 1                     Amazon     2            0  469822.0  33364.0
# 2                      Apple     3            0  365817.0  94680.0
# 3                 CVS Health     4            0  292111.0   7910.0
# 4         UnitedHealth Group     5            0  287597.0  17285.0
# ..                       ...   ...          ...       ...      ...
# 496       Roper Technologies   497           -9    6415.8   1152.6
# 497                     ARKO   498            0    6412.6     59.2
# 498  Frontier Communications   499          -97    6411.0      NaN
# 499                   Ameren   500          -31    6394.0    990.0
# 500                O-I Glass   501            0    6357.0    149.0
#
#      num. of employees              sector         city state newcomer  \
# 0            2300000.0           Retailing  Bentonville    AR       no
# ...

# %%
df.plot(x='Company', y='Revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='company', ylabel='revenue'>
